# %% [markdown]
# # Text processing and feature extraction

# %% [markdown]
# Regular env preparations.

# %%
import os
import os.path
import pandas as pd
import datetime
import matplotlib
import pickle
import numpy as np
from sklearn.svm import SVC
# %matplotlib inline

# %%
matplotlib.rcParams['figure.figsize'] = (14.0, 7.0)

# %%
DATA_PATH = 'D://DSworkshop//Avito'

# %%
train = pd.read_csv(os.path.join(DATA_PATH, 'train.csv'))

# %% [markdown]
# Let's see some data!

# %%
train.head(10)
# Out:
#         item_id       user_id                 region              city  \
# 0  b912c3c6a6ad  e00f8ff2eaf9   Свердловская область      Екатеринбург
# 1  2dac0150717d  39aeb48f0017      Самарская область            Самара
# 2  ba83aefab5dc  91e2f88dd6e3     Ростовская область    Ростов-на-Дону
# 3  02996f1dd2ea  bf5cccea572d              Татарстан  Набережные Челны
# 4  7c90be56d2ab  ef50846afc0b  Волгоградская область         Волгоград
# 5  51e0962387f7  bbfad0b1ad0a              Татарстан         Чистополь
# 6  c4f260a2b48a  08f469d2e6f7  Нижегородская область   Нижний Новгород
# 7  6b71309d6a8a  fef86baa002c          Пермский край             Пермь
# 8  c5b969cb63a2  055825270190   Оренбургская область          Оренбург
# 9  b1570962e68c  f9e8f831d94c  Нижегородская область   Нижний Новгород
#
#   parent_category_name               category_name  \
# 0          Личные вещи  Товары для детей и игрушки
# 1      Для дома и дачи           Мебель и интерьер
# 2  Бытовая электроника               Аудио и видео
# 3          Личные вещи  Товары для детей и игрушки
# 4            Транспорт                  Автомобили
# 5          Личные вещи  Товары для детей и игрушки
# 6      Для дома и дачи      Ремонт и строительство
# 7          Личные вещи   Одежда, обувь, аксессуары
# 8          Личные вещи   Одежда, обувь, аксессуары
# 9          Личные вещи      Детская одежда и обувь
#
#                        param_1        param_2     param_3  \
# 0    Постельные принадлежности            NaN         NaN
# 1                       Другое            NaN         NaN
# 2  Видео, DVD и Blu-ray плееры            NaN         NaN
# 3         Автомобильные кресла            NaN         NaN
# 4                   С пробегом     ВАЗ (LADA)        2110
# 5         Автомобильные кресла            NaN         NaN
# 6           Сантехника и сауна            NaN         NaN
# 7               Женская одежда         Джинсы          26
# 8               Женская одежда  Платья и юбки  > 50 (XXL)
# 9                  Для девочек          Обувь          25
#
#                                            title  \
# 0                          Кокоби(кокон для сна)
# 1                              Стойка для Одежды
# 2                                 Philips bluray
# 3                                     Автокресло
# 4                                 ВАЗ 2110, 2003
# 5                                    Авто люлька
# 6  Водонагреватель 100 литров нержавейка плоский
# 7                               Бойфренды colins
# 8                                         Платье
# 9              Полу ботиночки замш натур.Бамбини
#
#                                          description    price  \
# 0  Кокон для сна малыша,пользовались меньше месяц...    400.0
# 1          Стойка для одежды, под вешалки. С бутика.   3000.0
# 2  В хорошем состоянии, домашний кинотеатр с blu ...   4000.0
# 3                             Продам кресло от0-25кг   2200.0
# 4                           Все вопросы по телефону.  40000.0
# 5                                В хорошем состоянии   1300.0
# 6  Электро водонагреватель накопительный на 100 л...  11000.0
# 7                     Бойфренды в хорошем состоянии.    500.0
# 8                           54 раз мер очень удобное    500.0
# 9  По стельке 15.5см мерить приокский район. Цвет...    400.0
#
#    item_seq_number activation_date user_type  \
# 0                2      2017-03-28   Private
# 1               19      2017-03-26   Private
# 2                9      2017-03-20   Private
# 3              286      2017-03-25   Company
# 4                3      2017-03-16   Private
# 5                9      2017-03-28   Private
# 6              125      2017-03-23   Private
# 7               61      2017-03-25   Private
# 8               85      2017-03-17   Private
# 9              136      2017-03-22   Company
#
#                                                image  image_top_1  \
# 0  d10c7e016e03247a3bf2d13348fe959fe6f436c1caf64c...       1008.0
# 1  79c9392cc51a9c81c6eb91eceb8e552171db39d7142700...        692.0
# 2  b7f250ee3f39e1fedd77c141f273703f4a9be59db4b48a...       3032.0
# 3  e6ef97e0725637ea84e3d203e82dadb43ed3cc0a1c8413...        796.0
# 4  54a687a3a0fc1d68aed99bdaaf551c5c70b761b16fd0a2...       2264.0
# 5  eb6ad1231c59d3dc7e4020e724ffe8e4d302023ddcbb99...        796.0
# 6  0330f6ac561f5db1fa8226dd5e7e127b5671d44d075a98...       2823.0
# 7  9bab29a519e81c14f4582024adfebd4f11a4ac71d323a6...        567.0
# 8  75ce06d1f939a31dfb2af8ac55f08fa998fa336d13ee05...        415.0
# 9  54fb8521135fda77a860bfd2fac6bf46867ab7c06796e3...         46.0
#
#    deal_probability
# 0           0.12789
# 1           0.00000
# 2           0.43177
# 3           0.80323
# 4           0.20797
# 5           0.80323
# 6           0.00000
# 7           0.80323
# 8           0.00000
# 9           0.00000

# %% [markdown]
# How many unique categories and parent categories do we have?

# %%
print ("Num of parent categories: ",len(train["parent_category_name"].unique()))
print ("Num of categories: ",len(train["category_name"].unique()))
# Out:
# Num of parent categories:  9
# Num of categories:  47

# %% [markdown]
# How many unique (distinct) "param"s we have?

# %%
print("Num of distinct params: "
      ,len(set(train["param_1"].tolist()) | set(train["param_2"].tolist()) | set(train["param_3"].tolist())))
# Out:
# Num of distinct params:  1841

# %% [markdown]
# Nice. We think that combining those with the "params" attributes can generate the most informative features about of the data. But in order to engeneer those, we need to "categorize" it somehow. Lets see how many ads do not have any param mentioned within it.

# %%
ads_with_absent_params = len(train[train["param_1"].isnull() & train["param_2"].isnull() & train["param_3"].isnull()])
total_ads = train.shape[0]
print ("Absent params:",ads_with_absent_params)
print ("Total ads:",total_ads)
print ("Ratio of ads with no params at all:",100*ads_with_absent_params / float(total_ads),"%")
# Out:
# Absent params: 61576
# Total ads: 1503424
# Ratio of ads with no params at all: 4.09571750883317 %

# %% [markdown]
# ## Basic text feature extraction

# %% [markdown]
# ### Text length

# %%
def merge_params(row):
    sentence = ""
    for att in ["param_1","param_2","param_3"]:
        if not pd.isnull(row[att]):
            sentence += row[att] + " "
    return sentence

def count_words_safe(s):
    if pd.isnull(s):
        return 0
    return len(s.split())

train['title_word_count'] = train.apply(lambda row:count_words_safe(row['title']), axis=1)
train['description_word_count'] = train.apply(lambda row:count_words_safe(row['description']), axis=1)
train['params_total_word_count'] = train.apply(lambda row:count_words_safe(merge_params(row)), axis=1)
# Out:
#         item_id       user_id                 region              city  \
# 0  b912c3c6a6ad  e00f8ff2eaf9   Свердловская область      Екатеринбург
# 1  2dac0150717d  39aeb48f0017      Самарская область            Самара
# 2  ba83aefab5dc  91e2f88dd6e3     Ростовская область    Ростов-на-Дону
# 3  02996f1dd2ea  bf5cccea572d              Татарстан  Набережные Челны
# 4  7c90be56d2ab  ef50846afc0b  Волгоградская область         Волгоград
#
#   parent_category_name               category_name  \
# 0          Личные вещи  Товары для детей и игрушки
# 1      Для дома и дачи           Мебель и интерьер
# 2  Бытовая электроника               Аудио и видео
# 3          Личные вещи  Товары для детей и игрушки
# 4            Транспорт                  Автомобили
#
#                        param_1     param_2 param_3                  title  \
# 0    Постельные принадлежности         NaN     NaN  Кокоби(кокон для сна)
# 1                       Другое         NaN     NaN      Стойка для Одежды
# 2  Видео, DVD и Blu-ray плееры         NaN     NaN         Philips bluray
# 3         Автомобильные кресла         NaN     NaN             Автокресло
# 4                   С пробегом  ВАЗ (LADA)    2110         ВАЗ 2110, 2003
#
#          ...           price  item_seq_number  activation_date user_type  \
# 0        ...           400.0                2       2017-03-28   Private
# 1        ...          3000.0               19       2017-03-26   Private
# 2        ...          4000.0                9       2017-03-20   Private
# 3        ...          2200.0              286       2017-03-25   Company
# 4        ...         40000.0                3       2017-03-16   Private
#
#                                                image image_top_1  \
# 0  d10c7e016e03247a3bf2d13348fe959fe6f436c1caf64c...      1008.0
# 1  79c9392cc51a9c81c6eb91eceb8e552171db39d7142700...       692.0
# 2  b7f250ee3f39e1fedd77c141f273703f4a9be59db4b48a...      3032.0
# 3  e6ef97e0725637ea84e3d203e82dadb43ed3cc0a1c8413...       796.0
# 4  54a687a3a0fc1d68aed99bdaaf551c5c70b761b16fd0a2...      2264.0
#
#    deal_probability  title len  description len  params total len
# 0           0.12789          3                7                 2
# 1           0.00000          3                7                 1
# 2           0.43177          2               17                 5
# 3           0.80323          1                3                 2
# 4           0.20797          3                4                 5
#
# [5 rows x 21 columns]

# %%
train.describe()
# Out:
#               price  item_seq_number   image_top_1  deal_probability  \
# count  1.418062e+06     1.503424e+06  1.390836e+06      1.503424e+06
# mean   3.167081e+05     7.436740e+02  1.241932e+03      1.391306e-01
# std    6.689154e+07     5.572522e+03  9.704641e+02      2.600785e-01
# min    0.000000e+00     1.000000e+00  0.000000e+00      0.000000e+00
# 25%    5.000000e+02     9.000000e+00  4.250000e+02      0.000000e+00
# 50%    1.300000e+03     2.900000e+01  1.057000e+03      0.000000e+00
# 75%    7.000000e+03     8.800000e+01  2.217000e+03      1.508700e-01
# max    7.950101e+10     2.044290e+05  3.066000e+03      1.000000e+00
#
#           title len  description len  params total len  \
# count  1.503424e+06     1.503424e+06      1.503424e+06
# mean   3.325420e+00     2.512265e+01      3.590326e+00
# std    1.847104e+00     4.027831e+01      2.323865e+00
# min    1.000000e+00     0.000000e+00      0.000000e+00
# 25%    2.000000e+00     6.000000e+00      2.000000e+00
# 50%    3.000000e+00     1.200000e+01      3.000000e+00
# 75%    4.000000e+00     2.600000e+01      5.000000e+00
# max    2.100000e+01     7.110000e+02      9.000000e+00
#
#        title capital letters ratio  description capital letters ratio
# count                 1.503424e+06                          10.000000
# mean                  8.963850e-02                           0.037304
# std                   7.062030e-02                           0.017874
# min                   0.000000e+00                           0.000000
# 25%                   4.347826e-02                           0.031410
# 50%                   6.666667e-02                           0.042110
# 75%                   1.224490e-01                           0.047949
# max                   1.000000e+00                           0.060606

# %% [markdown]
# ### Capital letters ratio in text columns

# %%
def count_capitals_ratio_safe(s):
    if pd.isnull(s) or len(s)==0:
        return 0
    s = s.replace(" ","")
    return len([l for l in s if l.isupper()])/len(s)

train['title capital letters ratio'] = train.apply(lambda row:count_capitals_ratio_safe(row['title']), axis=1)
train['description capital letters ratio'] = train.apply(lambda row:count_capitals_ratio_safe(row['description']), axis=1)

# %%
train.describe()
# Out:
#               price  item_seq_number   image_top_1  deal_probability  \
# count  1.418062e+06     1.503424e+06  1.390836e+06      1.503424e+06
# mean   3.167081e+05     7.436740e+02  1.241932e+03      1.391306e-01
# std    6.689154e+07     5.572522e+03  9.704641e+02      2.600785e-01
# min    0.000000e+00     1.000000e+00  0.000000e+00      0.000000e+00
# 25%    5.000000e+02     9.000000e+00  4.250000e+02      0.000000e+00
# 50%    1.300000e+03     2.900000e+01  1.057000e+03      0.000000e+00
# 75%    7.000000e+03     8.800000e+01  2.217000e+03      1.508700e-01
# max    7.950101e+10     2.044290e+05  3.066000e+03      1.000000e+00
#
#           title len  description len  params total len  \
# count  1.503424e+06     1.503424e+06      1.503424e+06
# mean   3.325420e+00     2.512265e+01      3.590326e+00
# std    1.847104e+00     4.027831e+01      2.323865e+00
# min    1.000000e+00     0.000000e+00      0.000000e+00
# 25%    2.000000e+00     6.000000e+00      2.000000e+00
# 50%    3.000000e+00     1.200000e+01      3.000000e+00
# 75%    4.000000e+00     2.600000e+01      5.000000e+00
# max    2.100000e+01     7.110000e+02      9.000000e+00
#
#        title capital letters ratio  description capital letters ratio
# count                 1.503424e+06                       1.503424e+06
# mean                  8.963850e-02                       4.231141e-02
# std                   7.062030e-02                       7.094886e-02
# min                   0.000000e+00                       0.000000e+00
# 25%                   4.347826e-02                       1.530612e-02
# 50%                   6.666667e-02                       2.898551e-02
# 75%                   1.224490e-01                       4.761905e-02
# max                   1.000000e+00                       1.000000e+00

# %% [markdown]
# Lets see for example how CAPS only ads reflect deal_probability:

# %%
train[train['deal_probability']>0.8].corr()
# Out:
#                                       price  item_seq_number  image_top_1  \
# price                              1.000000        -0.000214     0.001594
# item_seq_number                   -0.000214         1.000000     0.004064
# image_top_1                        0.001594         0.004064     1.000000
# deal_probability                   0.010461        -0.009900     0.389754
# title len                         -0.002433         0.046895     0.031059
# description len                    0.001805         0.048347     0.053747
# params total len                  -0.002446        -0.020132    -0.375550
# title capital letters ratio        0.001785         0.013317     0.018078
# description capital letters ratio -0.001891         0.023082     0.033435
#
#                                    deal_probability  title len  \
# price                                      0.010461  -0.002433
# item_seq_number                           -0.009900   0.046895
# image_top_1                                0.389754   0.031059
# deal_probability                           1.000000   0.050423
# title len                                  0.050423   1.000000
# description len                            0.107157   0.270894
# params total len                          -0.044246   0.003494
# title capital letters ratio               -0.104329  -0.338729
# description capital letters ratio          0.041476   0.008214
#
#                                    description len  params total len  \
# price                                     0.001805         -0.002446
# item_seq_number                           0.048347         -0.020132
# image_top_1                               0.053747         -0.375550
# deal_probability                          0.107157         -0.044246
# title len                                 0.270894          0.003494
# description len                           1.000000         -0.062742
# params total len                         -0.062742          1.000000
# title capital letters ratio              -0.030480         -0.059104
# description capital letters ratio        -0.021094         -0.008300
#
#                                    title capital letters ratio  \
# price                                                 0.001785
# item_seq_number                                       0.013317
# image_top_1                                           0.018078
# deal_probability                                     -0.104329
# title len                                            -0.338729
# description len                                      -0.030480
# params total len                                     -0.059104
# title capital letters ratio                           1.000000
# description capital letters ratio                     0.036156
#
#                                    description capital letters ratio
# price                                                      -0.001891
# item_seq_number                                             0.023082
# image_top_1                                                 0.033435
# deal_probability                                            0.041476
# title len                                                   0.008214
# description len                                            -0.021094
# params total len                                           -0.008300
# title capital letters ratio                                 0.036156
# description capital letters ratio                           1.000000

# %%
train[train['title capital letters ratio'] < 0.1].corr()
# Out:
#                                       price  item_seq_number  image_top_1  \
# price                              1.000000         0.079868     0.053260
# item_seq_number                    0.079868         1.000000     0.100867
# image_top_1                        0.053260         0.100867     1.000000
# deal_probability                  -0.013547        -0.038214     0.188336
# title len                          0.080159         0.132168     0.224237
# description len                    0.068962         0.123762     0.187152
# params total len                  -0.031698        -0.048148    -0.553924
# title capital letters ratio       -0.091642        -0.166012    -0.172553
# description capital letters ratio -0.005817         0.017569     0.050671
#
#                                    deal_probability  title len  \
# price                                     -0.013547   0.080159
# item_seq_number                           -0.038214   0.132168
# image_top_1                                0.188336   0.224237
# deal_probability                           1.000000  -0.004503
# title len                                 -0.004503   1.000000
# description len                           -0.002538   0.282934
# params total len                          -0.117534  -0.142540
# title capital letters ratio               -0.019726  -0.558967
# description capital letters ratio         -0.001099   0.006504
#
#                                    description len  params total len  \
# price                                     0.068962         -0.031698
# item_seq_number                           0.123762         -0.048148
# image_top_1                               0.187152         -0.553924
# deal_probability                         -0.002538         -0.117534
# title len                                 0.282934         -0.142540
# description len                           1.000000         -0.156659
# params total len                         -0.156659          1.000000
# title capital letters ratio              -0.161931          0.055904
# description capital letters ratio         0.028826         -0.036450
#
#                                    title capital letters ratio  \
# price                                                -0.091642
# item_seq_number                                      -0.166012
# image_top_1                                          -0.172553
# deal_probability                                     -0.019726
# title len                                            -0.558967
# description len                                      -0.161931
# params total len                                      0.055904
# title capital letters ratio                           1.000000
# description capital letters ratio                     0.025068
#
#                                    description capital letters ratio
# price                                                      -0.005817
# item_seq_number                                             0.017569
# image_top_1                                                 0.050671
# deal_probability                                           -0.001099
# title len                                                   0.006504
# description len                                             0.028826
# params total len                                           -0.036450
# title capital letters ratio                                 0.025068
# description capital letters ratio                           1.000000

# %% [markdown]
# We can see a (very) slight correlation between description_len, and a (slight) negative correlation between deal_probability and "title capital letters ratio".
#
# Iterestingly we also see a negative correlation between "title capital letters ratio" and "image_top_1".

# %% [markdown]
# ## N-grams count

# %% [markdown]
# ### Unigrams (bag of words)

# %% [markdown]
# Create a bag of words

# %% [markdown]
# ### Bigrams

# %% [markdown]
# ### Trigrams

# %% [markdown]
# ## Tagging and tags analysis

# %% [markdown]
# ## Semantic analysis

# %% [markdown]
# ### Is the product popular (how many buy this product)?

# %% [markdown]
# We first need somehow to determine what is the product being sold. We'll do this by recognizing the "head" noun in the title.

# %% [markdown]
# ### Is the product new / good shape?

# %% [markdown]
# Look for words with similar embeddings and semantic tags (k, learn this k).

# %% [markdown]
# Find a way to enrich popular products lines (stuff like avg. price and/or product condition semantics - see below)

# %% [markdown]
# ## Word embeddings for clustering params and other keywords.

# %% [markdown]
# As most of the ads have set "param", we turn to use word embeddings to represent the "params" description. We've downloaded a ready-to-use russian word embeddings from "Polyglot":
# https://sites.google.com/site/rmyeid/projects/polyglot.
# Let's load those:

# %%
with open(os.path.join(DATA_PATH, 'polyglot-ru.pkl'), 'rb') as f:
    u = pickle._Unpickler(f)
    u.encoding = 'latin1'
    words, embeddings = u.load()
print("Emebddings shape is {}".format(embeddings.shape))
# Out:
# Emebddings shape is (100004, 64)

# %% [markdown]
# Some othe Russian word2vec to explore later on:
# https://github.com/nlpub/russe-evaluation/tree/master/russe/measures/word2vec

# %% [markdown]
# Let's see how many of the (meaningful) words from params appear in the wrodEmbeddings dictionary.
# We first filter out Stopwords. We've examined 3 lists of stopwords:
# * https://gist.github.com/menzenski/7047705
# * https://www.ranks.nl/stopwords/russian
# * https://www.symantec.com/connect/downloads/russian-stop-words-list
#
# After consulting with our russian linguist, we've picked the third option because it had the least amount of words (the first two would filter out important semantic info).

# %%
stopwords = set()
import codecs
with codecs.open(os.path.join(DATA_PATH, 'stopwords_ru.txt'), encoding='cp1251') as ins:
    for w in ins:
        word = w.strip("\r\n")
        word = word.strip("\n")
        stopwords.add(word)
        stopwords.add(word.upper())
        stopwords.add(word[0].upper() + word[1:])

# %% [markdown]
# Now we proceed to check how many meaningful words appear in "params".

# %%
# Returns true iff *any* word in sentense is present in words.
def param_meaningfull_word_ratio(row):
    sentence = ""
    for att in ["param_1","param_2","param_3"]:
        if not pd.isnull(row[att]):
            sentence += row[att] + " "

    count = 0
    present = 0
    for w in sentence.split():
        count += 1
        if (w in words) and (w not in stopwords):
            present += 1
    return present / float(count)

# We sample 10,000 ads.
N = 10000
train_present_params = train[~(train["param_1"].isnull() & train["param_2"].isnull() & train["param_3"].isnull())].sample(N)
train_present_params['param_1_has_meaningful'] = train_present_params.apply(param_meaningfull_word_ratio, axis=1)
print("We sampled",N,"rows.")
num_meaningful = len(train_present_params[train_present_params['param_1_has_meaningful'] > 0.0])
print(num_meaningful,"Have meaningful words in their params (That's",num_meaningful/float(N)*100,"%).")
# Out:
# We sampled 10000 rows.
# 7865 Have meaningful words in their params (That's 78.64999999999999 %).
